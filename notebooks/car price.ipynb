# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("CarPrice_Assignment.csv")
df_=df.copy()

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.drop("car_ID", axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
cat_col=[col for col in df_.columns if df_[col].dtypes=="object"]
num_col=[col for col in df_.columns if df_[col].dtypes !="oject"]
num_col.remove("price")

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_["price"], kde=True, bins=30, color='skyblue')
plt.title(f'Distribution of price')
plt.xlabel("price")
plt.ylabel('Count')
plt.show()

# %%
for col in num_col:
    plt.figure(figsize=(8,5))
    sns.scatterplot(x=col , y="price", data=df_ )
    print(f"{col } vs price")
    plt.show()
# Out:
# car_ID vs price
# symboling vs price
# CarName vs price
# fueltype vs price
# aspiration vs price
# doornumber vs price
# carbody vs price
# drivewheel vs price
# enginelocation vs price
# wheelbase vs price
# carlength vs price
# carwidth vs price
# carheight vs price
# curbweight vs price
# enginetype vs price
# cylindernumber vs price
# enginesize vs price
# fuelsystem vs price
# boreratio vs price
# stroke vs price
# compressionratio vs price
# horsepower vs price
# peakrpm vs price
# citympg vs price
# highwaympg vs price

# %%
for col in cat_col:
    plt.figure(figsize=(8,5))
    sns.boxplot(x=col , y="price", data=df_ )
    print(f"{col } vs price")
    plt.show()
# Out:
# CarName vs price
# fueltype vs price
# aspiration vs price
# doornumber vs price
# carbody vs price
# drivewheel vs price
# enginelocation vs price
# enginetype vs price
# cylindernumber vs price
# fuelsystem vs price

# %%
df.symboling.unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2])

# %% [markdown]
# # Symboling Value	Meaning
# -3	Very safe
# -2	Safe
# -1	Slightly safe
# 0	Average risk
# +1	Slightly risky
# +2	Risky
# +3	Very risky

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %% [markdown]
# # the car name column was removed because it has a large number of unique text values and contains redundant information already represented by other numerical and categorical features, which can negatively affect model generalization.

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.fueltype.unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df.aspiration.unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df.carbody.unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df.drivewheel.unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df.enginelocation.unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df.wheelbase.unique()
# Out:
# array([ 88.6,  94.5,  99.8,  99.4, 105.8,  99.5, 101.2, 103.5, 110. ,
#         88.4,  93.7, 103.3,  95.9,  86.6,  96.5,  94.3,  96. , 113. ,
#        102. ,  93.1,  95.3,  98.8, 104.9, 106.7, 115.6,  96.6, 120.9,
#        112. , 102.7,  93. ,  96.3,  95.1,  97.2, 100.4,  91.3,  99.2,
#        107.9, 114.2, 108. ,  89.5,  98.4,  96.1,  99.1,  93.3,  97. ,
#         96.9,  95.7, 102.4, 102.9, 104.5,  97.3, 104.3, 109.1])

# %%
df.doornumber.unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.carlength
# Out:
# 0      168.8
# 1      168.8
# 2      171.2
# 3      176.6
# 4      176.6
#        ...
# 200    188.8
# 201    188.8
# 202    188.8
# 203    188.8
# 204    188.8
# Name: carlength, Length: 205, dtype: float64

# %%
df.carwidth
# Out:
# 0      64.1
# 1      64.1
# 2      65.5
# 3      66.2
# 4      66.4
#        ...
# 200    68.9
# 201    68.8
# 202    68.9
# 203    68.9
# 204    68.9
# Name: carwidth, Length: 205, dtype: float64

# %%
df.carheight
# Out:
# 0      48.8
# 1      48.8
# 2      52.4
# 3      54.3
# 4      54.3
#        ...
# 200    55.5
# 201    55.5
# 202    55.5
# 203    55.5
# 204    55.5
# Name: carheight, Length: 205, dtype: float64

# %%
df.curbweight
# Out:
# 0      2548
# 1      2548
# 2      2823
# 3      2337
# 4      2824
#        ...
# 200    2952
# 201    3049
# 202    3012
# 203    3217
# 204    3062
# Name: curbweight, Length: 205, dtype: int64

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.enginetype.unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df.enginesize
# Out:
# 0      130
# 1      130
# 2      152
# 3      109
# 4      136
#       ...
# 200    141
# 201    141
# 202    173
# 203    145
# 204    141
# Name: enginesize, Length: 205, dtype: int64

# %%
df.fuelsystem.unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
df.boreratio
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: boreratio, Length: 205, dtype: float64

# %%
df.stroke
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: float64

# %%
df.compressionratio
# Out:
# 0       9.0
# 1       9.0
# 2       9.0
# 3      10.0
# 4       8.0
#        ...
# 200     9.5
# 201     8.7
# 202     8.8
# 203    23.0
# 204     9.5
# Name: compressionratio, Length: 205, dtype: float64

# %%
df.horsepower
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: int64

# %%
df.peakrpm
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peakrpm, Length: 205, dtype: int64

# %%
df.citympg
# Out:
# 0      21
# 1      21
# 2      19
# 3      24
# 4      18
#        ..
# 200    23
# 201    19
# 202    18
# 203    26
# 204    19
# Name: citympg, Length: 205, dtype: int64

# %%
df.highwaympg
# Out:
# 0      27
# 1      27
# 2      26
# 3      30
# 4      22
#        ..
# 200    28
# 201    25
# 202    23
# 203    27
# 204    25
# Name: highwaympg, Length: 205, dtype: int64

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [markdown]
# """ 1]we use Ohe for  [fueltype carbody, drivewheel, enginelocation, enginetype , fuelsystem , aspiration ]
# feature
#
# 2] we use manual maping for [doornumber, cylindernumber] because it has real meaning . and chage the data types to int ."""

# %%
df=pd.get_dummies(df,columns=["fueltype","carbody", "drivewheel", "enginelocation", "enginetype" , "fuelsystem" , "aspiration"], drop_first=False)

# %%
df["doornumber"]=df["doornumber"].replace({"two":2,"four":4}).astype(int)

# %%
df["cylindernumber"]=df["cylindernumber"].replace({"four":4,"six":6,"five":5,"three":3,"twelve":12,"two":2,"eight":8})

# %%
df
# Out:
#      symboling                   CarName  doornumber  wheelbase  carlength  \
# 0            3        alfa-romero giulia           2       88.6      168.8
# 1            3       alfa-romero stelvio           2       88.6      168.8
# 2            1  alfa-romero Quadrifoglio           2       94.5      171.2
# 3            2               audi 100 ls           4       99.8      176.6
# 4            2                audi 100ls           4       99.4      176.6
# ..         ...                       ...         ...        ...        ...
# 200         -1           volvo 145e (sw)           4      109.1      188.8
# 201         -1               volvo 144ea           4      109.1      188.8
# 202         -1               volvo 244dl           4      109.1      188.8
# 203         -1                 volvo 246           4      109.1      188.8
# 204         -1               volvo 264gl           4      109.1      188.8
#
# ...

# %%
df.drop("CarName", axis=1 , inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # to many features and it is hard to understand the corealation between them .

# %%
df
# Out:
#      symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0            3           2       88.6      168.8      64.1       48.8
# 1            3           2       88.6      168.8      64.1       48.8
# 2            1           2       94.5      171.2      65.5       52.4
# 3            2           4       99.8      176.6      66.2       54.3
# 4            2           4       99.4      176.6      66.4       54.3
# ..         ...         ...        ...        ...       ...        ...
# 200         -1           4      109.1      188.8      68.9       55.5
# 201         -1           4      109.1      188.8      68.8       55.5
# 202         -1           4      109.1      188.8      68.9       55.5
# 203         -1           4      109.1      188.8      68.9       55.5
# 204         -1           4      109.1      188.8      68.9       55.5
#
#      curbweight  cylindernumber  enginesize  boreratio  ...  fuelsystem_1bbl  \
# ...

# %%
x=df.drop("price",axis=1)
y=df["price"]

# %%
x
# Out:
#      symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0            3           2       88.6      168.8      64.1       48.8
# 1            3           2       88.6      168.8      64.1       48.8
# 2            1           2       94.5      171.2      65.5       52.4
# 3            2           4       99.8      176.6      66.2       54.3
# 4            2           4       99.4      176.6      66.4       54.3
# ..         ...         ...        ...        ...       ...        ...
# 200         -1           4      109.1      188.8      68.9       55.5
# 201         -1           4      109.1      188.8      68.8       55.5
# 202         -1           4      109.1      188.8      68.9       55.5
# 203         -1           4      109.1      188.8      68.9       55.5
# 204         -1           4      109.1      188.8      68.9       55.5
#
#      curbweight  cylindernumber  enginesize  boreratio  ...  fuelsystem_1bbl  \
# ...

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((184, 45), (21, 45), (184,), (21,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_train_scaler=scaler.fit_transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
models={
    "linear regression": LinearRegression(),
    "SVR": SVR(),
    "Decision tree":DecisionTreeRegressor(),
    "random forest":RandomForestRegressor()
}

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
result=[]

for name ,model in models.items():

    if name =="SVR":
        model.fit(x_train_scaler,y_train)
        predict=model.predict(x_test_scaler)

    else:
        model.fit(x_train,y_train)
        predict=model.predict(x_test)

    mae=mean_absolute_error(y_test,predict)
    mse=mean_squared_error(y_test,predict)
    r2=r2_score(y_test,predict)
    result.append([name,mae,mse,r2])

result = pd.DataFrame(
    result,
    columns=["Model", "MAE", "MSE", "R2"]
)

result
# Out:
#                Model          MAE           MSE        R2
# 0  linear regression  2309.431887  1.352809e+07  0.462174
# 1                SVR  3754.473326  2.537551e+07 -0.008835
# 2      Decision tree  1540.380952  6.516871e+06  0.740914
# 3      random forest  1180.391479  3.151408e+06  0.874712

# %%
from sklearn.model_selection import  RandomizedSearchCV

# %%
param_dist = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

rf = RandomForestRegressor(random_state=42)

search = RandomizedSearchCV(
    rf,
    param_dist,
    n_iter=20,
    cv=5,
    scoring="r2",
    random_state=42,
    n_jobs=-1
)

search.fit(x_train, y_train)
search.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_depth': 30}

# %%
best_rf = search.best_estimator_

# %%
y_pred = best_rf.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

mae, rmse, r2
# Out:
# (1189.6174721693124, np.float64(1765.114235568602), 0.8761343227117944)

# %%
pd.DataFrame({
    "Model": ["Random Forest (Before)", "Random Forest (After)"],
    "R2": [0.8747, r2],
    "MAE": [1180.39, mae]
})
# Out:
#                     Model        R2          MAE
# 0  Random Forest (Before)  0.874700  1180.390000
# 1   Random Forest (After)  0.876134  1189.617472
